# %% [markdown]
# <a href="https://colab.research.google.com/github/WANSHKUMBHALKAR/AI-lab/blob/main/pandas_numpy_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
Mylist = [10,20,30,40,50,60,70,80]
res = pd.Series(Mylist)
print("Series = \n",res)
# Out:
# Series =
#  0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# 7    80
# dtype: int64

# %%
import numpy as np
arr = np.array((1,2,3))
print("array = ",arr)
print(type(arr))
# Out:
# array =  [1 2 3]
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpts = np.array([0,4])
ypts = np.array([0,1000])
plt.plot(xpts,ypts)
plt.show()
