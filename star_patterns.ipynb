# %% [markdown]
# <a href="https://colab.research.google.com/github/WANSHKUMBHALKAR/AI-lab/blob/main/star_patterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(5):
  print("*", end=" ")
# Out:
# * * * * *

# %%
rows = 5

for i in range(1, rows+1):
  for j in range(i):
    print("*", end=" ")
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
co_id = 1234
co_username = "w"

username = input("enter username: ")
id = int(input ("enter id: "))

if (username==co_username and id==co_id):
  print("ssuccess")
else:
  print("fail")
# Out:
# enter username: w
# enter id: 1234
# ssuccess

# %%
rows=5
for i in range(rows, 0, -1):
 for j in range(i):
  print("*", end=" ")
 print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
rows=5
for i in range(1, rows+1):
  print(" "* (rows-1), end=" ")

  for j in range(i):
    print("*", end=" ")

  print()
# Out:
#      *
#      * *
#      * * *
#      * * * *
#      * * * * *
